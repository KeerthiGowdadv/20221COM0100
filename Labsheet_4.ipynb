# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthiGowdadv/20221COM0100/blob/main/Labsheet_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
meteorites=pd.read_csv('/content/Meteorite_Landings.csv',nrows=5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit': 50_000}
)

if response.ok:
  payload = response.json()
else:
  print(f'Request was not successful and returned code : {response.status_code}')
  payload = None

# %%
import pandas as pd

df=pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorites.tail()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5 non-null      object
#  1   id           5 non-null      int64
#  2   nametype     5 non-null      object
#  3   recclass     5 non-null      object
#  4   mass (g)     5 non-null      int64
#  5   fall         5 non-null      object
#  6   year         5 non-null      object
#  7   reclat       5 non-null      float64
#  8   reclong      5 non-null      float64
#  9   GeoLocation  5 non-null      object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 528.0+ bytes

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites[['name','mass (g)']]
# Out:
#        name  mass (g)
# 0    Aachen        21
# 1    Aarhus       720
# 2      Abee    107000
# 3  Acapulco      1914
# 4   Achiras       780

# %%
meteorites[100:104]
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# ...

# %%
meteorites.iloc[100:104,[0,3,4,6]]
# Out:
# Empty DataFrame
# Columns: [name, recclass, mass (g), year]
# Index: []

# %%
meteorites.loc[100:104,'mass (g)':'year']
# Out:
# Empty DataFrame
# Columns: [mass (g), fall, year]
# Index: []

# %%
(meteorites['mass (g)']>50) & (meteorites.fall=='Found')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
meteorites[(meteorites['mass (g)'] > 1e6) & (meteorites.fall =='Fell')]
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation]
# Index: []

# %%
meteorites.query
# Out:
# <bound method DataFrame.query of        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)  >

# %%
meteorites.fall.value_counts()
# Out:
# Fell    5
# Name: fall, dtype: int64

# %%
meteorites.fall.value_counts(normalize=True)
# Out:
# Fell    1.0
# Name: fall, dtype: float64

# %%
meteorites['mass (g)'].mean()
# Out:
# 22087.0

# %%
meteorites['mass (g)'].quantile([0.01,0.05,0.5,0.95,0.99])
# Out:
# 0.01        48.96
# 0.05       160.80
# 0.50       780.00
# 0.95     85982.80
# 0.99    102796.56
# Name: mass (g), dtype: float64

# %%
meteorites['mass (g)'].median()
# Out:
# 780.0

# %%
meteorites['mass (g)'].max()
# Out:
# 107000

# %%
meteorites.loc[meteorites['mass (g)'].idxmax()]
# Out:
# name                             Abee
# id                                  6
# nametype                        Valid
# recclass                          EH4
# mass (g)                       107000
# fall                             Fell
# year           01/01/1952 12:00:00 AM
# reclat                       54.21667
# reclong                        -113.0
# GeoLocation        (54.21667, -113.0)
# Name: 2, dtype: object

# %%
meteorites.recclass.nunique()
# Out:
# 5

# %%
meteorites.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6'], dtype=object)

# %%
meteorites.describe(include='all')
# Out:
#           name          id nametype recclass       mass (g)  fall  \
# count        5    5.000000        5        5       5.000000     5
# unique       5         NaN        1        5            NaN     1
# top     Aachen         NaN    Valid       L5            NaN  Fell
# freq         1         NaN        5        1            NaN     5
# mean       NaN   77.800000      NaN      NaN   22087.000000   NaN
# std        NaN  163.383598      NaN      NaN   47472.657372   NaN
# min        NaN    1.000000      NaN      NaN      21.000000   NaN
# 25%        NaN    2.000000      NaN      NaN     720.000000   NaN
# 50%        NaN    6.000000      NaN      NaN     780.000000   NaN
# 75%        NaN   10.000000      NaN      NaN    1914.000000   NaN
# max        NaN  370.000000      NaN      NaN  107000.000000   NaN
#
#                           year     reclat     reclong        GeoLocation
# count                        5   5.000000    5.000000                  5
# ...
